# %% [markdown]
# # Лабораторная работа 3
# ## Барицентрическая форма полинома Лагранжа

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### Узлы и значения функции в узлах интерполирования

# %%
x=[0,math.pi/6,math.pi/4,math.pi/3,math.pi/2]
y=[]
for i in range(5):
    y.append(math.cos(x[i]))

# %% [markdown]
# ### Рассчет коэфициентов w и Ak

# %%
w=[]
product=1
for i in range(5):
    for j in range(5):
        if(i!=j):
            product*=(x[i]-x[j])
    w.append(product)
    product=1

# %%
A=[]
for i in range(5):
    A.append(1/w[i])

# %% [markdown]
# ### Коэффициенты Ak

# %%
print(A)
# Out:
# [1.4783014446745448, -13.304713002070901, 23.652823114792717, -13.304713002070905, 1.4783014446745442]

# %% [markdown]
# ### Построение полинома

# %%
def Pn(X):
    num=0
    denom=0
    for i in range(5):
        num+=((A[i]*y[i])/(X-x[i]))
        denom+=(A[i]/(X-x[i]))
    return num/denom

# %% [markdown]
# ### Сравнение результатов

# %%
xx=[math.pi/12, math.pi*5/12, math.pi*7/24]
yy=[]
yycos=[]
for i in range(3):
    yy.append(Pn(xx[i]))
    yycos.append(math.cos(xx[i]))

# %%
yy
# Out:
# [0.9661196634515765, 0.25858790872102827, 0.608785325608204]

# %%
yycos
# Out:
# [0.9659258262890683, 0.25881904510252074, 0.6087614290087208]

# %% [markdown]
# ### Абсолютная погрешность интерполирования

# %%
delta=[]
for i in range(3):
    delta.append(abs(yycos[i]-yy[i]))

# %%
delta
# Out:
# [0.0001938371625082036, 0.0002311363814924694, 2.3896599483208547e-05]

# %% [markdown]
# ### Графики

# %%
t=np.linspace(0,math.pi/2,100)
plt.figure(figsize=(20, 10))
plt.subplot(1,3,1)
plt.title("cos(x)")
plt.plot(t,np.cos(t),color='k')
plt.subplot(1,3,2)
plt.title("interpolated")
plt.plot(t,Pn(t),color='m')
plt.subplot(1,3,3)
x_x=np.array([math.pi/12, math.pi*5/12, math.pi*7/24])
plt.scatter(x_x,Pn(x_x),color='m')
plt.plot(t,np.cos(t),color='k')
plt.figure(figsize=(30, 3))
# Out:
# /var/folders/f5/03wh68ts7fqg3335vdfh1mm80000gn/T/ipykernel_5879/2033467089.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   num+=((A[i]*y[i])/(X-x[i]))
# /var/folders/f5/03wh68ts7fqg3335vdfh1mm80000gn/T/ipykernel_5879/2033467089.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   denom+=(A[i]/(X-x[i]))
# /var/folders/f5/03wh68ts7fqg3335vdfh1mm80000gn/T/ipykernel_5879/2033467089.py:7: RuntimeWarning: invalid value encountered in true_divide
#   return num/denom

# %% [markdown]
# # Лабораторная работа 4
#
# ## Схема Эйткена

# %%
L1=[]
element=0
for i in range(4):
    element=(1/(x[i+1]-x[i]))*(y[i]*np.poly([x[i+1]])-y[i+1]*np.poly([x[i]]))
    L1.append(element)

# %%
for i in range(4):
    print(np.poly1d(L1[i]))
# Out:
#
# 0.2559 x - 1
#
# 0.607 x - 1.184
#
# 0.7911 x - 1.328
#
# 0.9549 x - 1.5

# %%
L2=[]
element=0
for i in range(3):
    element=(1/(x[i+2]-x[i]))*np.polysub(np.polymul(L1[i],(-1)*np.poly([x[i+2]])),np.polymul(L1[i+1],(-1)*np.poly([x[i]])))
    L2.append(element)

# %%
for i in range(3):
    print(np.poly1d(L2[i]))
# Out:
#         2
# 0.4471 x + 0.02177 x - 1
#         2
# 0.3515 x + 0.1469 x - 1.039
#         2
# 0.2086 x + 0.4088 x - 1.157

# %%
L3=[]
element=0
for i in range(2):
    element=(1/(x[i+3]-x[i]))*np.polysub(np.polymul(L2[i],(-1)*np.poly([x[i+3]])),np.polymul(L2[i+1],(-1)*np.poly([x[i]])))
    L3.append(element)

# %%
for i in range(2):
    print(np.poly1d(L3[i]))
# Out:
#           3          2
# -0.09125 x + 0.5666 x - 0.01576 x - 1
#          3          2
# -0.1365 x + 0.6731 x - 0.09636 x - 0.9805

# %%
L4=(1/(x[4]-x[0]))*np.polysub(np.polymul(L3[1],(-1)*np.poly([x[0]])),np.polymul(L3[0],(-1)*np.poly([x[4]])))

# %%
print(np.poly1d(L4))
# Out:
#         4          3          2
# 0.0288 x + 0.0234 x - 0.5152 x + 0.003354 x + 1

# %%
t=np.linspace(0,math.pi/2,100)
plt.figure(figsize=(20, 10))
plt.subplot(1,3,1)
plt.title("cos(x)")
plt.plot(t,np.cos(t),color='k')
plt.subplot(1,3,2)
plt.title("interpolated")
plt.plot(t,np.polyval(L4,t),color='m')
plt.subplot(1,3,3)
x_x=np.array([math.pi/12, math.pi*5/12, math.pi*7/24])
plt.scatter(x_x,np.polyval(L4,x_x),color='m')
plt.plot(t,np.cos(t),color='k')
plt.figure(figsize=(30, 3))

# %%
import pandas as pd

# %%
list=[x, y]
poly1=[]
poly1.append('-')
for i in range(4):
    poly1.append(str(np.poly1d(L1[i])))
    
poly2=[]
poly2.append('-')
poly2.append('-')
for i in range(3):
    poly2.append(str(np.poly1d(L2[i])))
    
poly3=[]
poly3.append('-')
poly3.append('-')
poly3.append('-')
for i in range(2):
    poly3.append(str(np.poly1d(L3[i])))
    
poly4=[]
poly4.append('-')
poly4.append('-')
poly4.append('-')
poly4.append('-')
poly4.append(str(np.poly1d(L4)))
data={'x':x, 'f(x)':y,'L1':poly1,'L2':poly2,'L3':poly3,'L4':poly4}
dataFrame=pd.DataFrame(data)

# %%
dataFrame
# Out:
#           x          f(x)                   L1  \
# 0  0.000000  1.000000e+00                    -
# 1  0.523599  8.660254e-01       \n0.2559 x - 1
# 2  0.785398  7.071068e-01    \n0.607 x - 1.184
# 3  1.047198  5.000000e-01   \n0.7911 x - 1.328
# 4  1.570796  6.123234e-17     \n0.9549 x - 1.5
#
#                                        L2  \
# 0                                       -
# 1                                       -
# 2             2\n0.4471 x + 0.02177 x - 1
# 3          2\n0.3515 x + 0.1469 x - 1.039
# 4          2\n0.2086 x + 0.4088 x - 1.157
#
#                                                   L3  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3            3          2\n-0.09125 x + 0.5666 x ...
# 4           3          2\n-0.1365 x + 0.6731 x - ...
#
#                                                   L4
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4          4          3          2\n0.0288 x + 0....
