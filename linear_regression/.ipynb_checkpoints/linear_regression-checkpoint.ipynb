# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('states.csv')
n = data.shape[0]

# %%
graduation = data['hs_grad']
poverty = data['poverty']

# %%
plt.scatter(graduation, poverty)
plt.xlabel('graduation')
plt.ylabel('poverty')
# Out:
# Text(0, 0.5, 'poverty')

# %%
graduation_mean = graduation.mean()
poverty_mean = poverty.mean()
graduation_variance = sum((graduation - graduation_mean) ** 2) / n
poverty_variance = sum((poverty - poverty_mean) ** 2) / n
cov = sum((graduation - graduation_mean) * (poverty - poverty_mean)) / n
sd_graduation = graduation_variance ** 0.5
sd_poverty = poverty_variance ** 0.5
cor = cov / (sd_graduation * sd_poverty)

# %%
slope = (sd_poverty / sd_graduation) * cor
intercept = poverty_mean - slope * graduation_mean

# %%
intercept
# Out:
# 64.78096577010206

# %%
slope
# Out:
# -0.6212167177940103

# %%
x = np.array([72, 98])
plt.scatter(graduation, poverty)
plt.plot(x, intercept + slope * x)
plt.grid()
plt.title('y = {} x + {}'.format(slope, intercept))
plt.xlabel('graduation')
plt.ylabel('poverty')
# Out:
# Text(0, 0.5, 'poverty')

# %%
white = data['white']

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure(figsize = (20, 14))
ax = plt.axes(projection ='3d')
ax.scatter3D(graduation, poverty, white)

# %%
delta = round((max(graduation) - min(graduation)) / (1 + np.math.log2(n)))
plt.hist(graduation, bins=np.arange(min(graduation), max(graduation) + delta - 1, delta))
# Out:
# (array([ 2.,  7.,  4.,  4., 10., 15.,  7.]),
#  array([77.2, 79.2, 81.2, 83.2, 85.2, 87.2, 89.2, 91.2]),
#  <BarContainer object of 7 artists>)

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df.Rk
x = df.GD.values.reshape(-1,1)
model = LinearRegression().fit(graduation, poverty)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 model = LinearRegression().fit(graduation, poverty)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# ...
