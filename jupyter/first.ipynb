# %%
integrals=[]
e=2.71828
integrals.append(1-1/e)
for i in range(20):
    print(integrals[i])
    integrals.append(1-i*integrals[i])
# %matplotlib inline    
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(range(21),integrals)
# Out:
# 0.6321203113733684
# 1.0
# 0.0
# 1.0
# -2.0
# 9.0
# -44.0
# 265.0
# -1854.0
# 14833.0
# -133496.0
# 1334961.0
# -14684570.0
# 176214841.0
# -2290792932.0
# 32071101049.0
# -481066515734.0
# 7697064251745.0
# -130850092279664.0
# 2355301661033953.0
